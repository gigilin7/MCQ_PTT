# %% [markdown]
# # 開始前請先變更執行階段類型為GPU

# %% [markdown]
# ## 下載PTT資料

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1LLH6bLj4OTS0X3x6YnfpggztH1w7Ivra' -O pttdata45.zip
# Out:
# --2023-02-21 08:17:05--  https://docs.google.com/uc?export=download&id=1LLH6bLj4OTS0X3x6YnfpggztH1w7Ivra
# Resolving docs.google.com (docs.google.com)... 74.125.197.139, 74.125.197.101, 74.125.197.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/80oa1qsuq2rc7mj2if24icptr2urgsh2/1676967375000/02928050404646572593/*/1LLH6bLj4OTS0X3x6YnfpggztH1w7Ivra?e=download&uuid=bdbafa09-df93-4045-9b6c-633eef8d18df [following]
# ...
# --2023-02-21 08:17:10--  https://doc-10-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/80oa1qsuq2rc7mj2if24icptr2urgsh2/1676967375000/02928050404646572593/*/1LLH6bLj4OTS0X3x6YnfpggztH1w7Ivra?e=download&uuid=bdbafa09-df93-4045-9b6c-633eef8d18df
# ...

# %%
# !unzip pttdata45.zip
# Out:
# Archive:  pttdata45.zip
#   inflating: pttdata45.json

# %%
# !mkdir corpus

# %% [markdown]
# ## 將原始資料轉換成 pysiniri 可以讀取的資料格式

# %%
import json
json_corpus=[]
with open('pttdata45.json','r',encoding='utf-8') as f:
  data=json.load(f)
  print(data[0])
  cnt=1
  for i in data:
    json_corpus.append({"id":str(cnt),"contents":data[cnt-1]['_source']["content"]})
    cnt+=1    

with open('corpus/pttdata.json','w',encoding='utf-8') as f:
  json.dump(json_corpus, f, ensure_ascii = False, indent=4)
# Out:
# {'_index': 'article2', '_type': '_doc', '_id': 'd30166ec5abb4d5b45cf100450a7517a', '_score': 1.0, '_source': {'article_url': 'https://www.ptt.cc/bbs/HatePolitics/M.1629105893.A.901.html', 'type': 'article', 'article_id': 'M.1629105893.A.901', 'article_title': '[討論] 覺青:高端比聯亞 相當勞斯萊斯比納智捷', 'user_id': 'valkyrie', 'user_nickname': '1234', 'board': 'HatePolitics', 'content': '認識一個覺青\n\n提到聯亞沒有通過EUA\n\n他說這完全在他的預料之中\n\n他說因為高端疫苗的品質 就相當於是疫苗界的勞斯萊斯\n\n還說但是聯亞的品質 只相當於疫苗界的納智捷\n\n所以高端通過 聯亞沒過 完全在預料之中\n\n…\n\n真的有差這麼多嗎？\n\n有沒有八卦?\n\n--', 'date': 1629105891, 'ip': '223.141.95.55'}}

# %%
json_corpus[0]
# Out:
# {'id': '1',
#  'contents': '認識一個覺青\n\n提到聯亞沒有通過EUA\n\n他說這完全在他的預料之中\n\n他說因為高端疫苗的品質 就相當於是疫苗界的勞斯萊斯\n\n還說但是聯亞的品質 只相當於疫苗界的納智捷\n\n所以高端通過 聯亞沒過 完全在預料之中\n\n…\n\n真的有差這麼多嗎？\n\n有沒有八卦?\n\n--'}

# %%
len(json_corpus)
# Out:
# 31066

# %%
# !pip install pyserini
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 86.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 103.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 93.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 102.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 108.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 KB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 5.4 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 10.7 MB/s eta 0:00:00
# ...

# %%
# !pip install rouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## 下載中文w2v model、QGmodel 並解壓縮

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1AjsBZY7tyke_jjspnEGmZqZmsQqE9UP2' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1AjsBZY7tyke_jjspnEGmZqZmsQqE9UP2" -O w2v_zh.zip && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WJtiNWmiFSz1gIMQNEaxXGVBL0Cjnch0' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1WJtiNWmiFSz1gIMQNEaxXGVBL0Cjnch0" -O model.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-02-21 08:17:54--  https://docs.google.com/uc?export=download&confirm=t&id=1AjsBZY7tyke_jjspnEGmZqZmsQqE9UP2
# Resolving docs.google.com (docs.google.com)... 142.250.107.138, 142.250.107.113, 142.250.107.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.107.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m2a1jsggeog0fjka0n0ue2l3i3krmloa/1676967450000/02928050404646572593/*/1AjsBZY7tyke_jjspnEGmZqZmsQqE9UP2?e=download&uuid=344344e8-0f73-4112-9835-c89f0fe3040e [following]
# ...
# --2023-02-21 08:17:54--  https://doc-10-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m2a1jsggeog0fjka0n0ue2l3i3krmloa/1676967450000/02928050404646572593/*/1AjsBZY7tyke_jjspnEGmZqZmsQqE9UP2?e=download&uuid=344344e8-0f73-4112-9835-c89f0fe3040e
# ...

# %%
# !unzip w2v_zh.zip
# !unzip model.zip
# Out:
# Archive:  w2v_zh.zip
#    creating: w2v_zh/
#   inflating: w2v_zh/word2vec_wiki_zh.model.bin
#   inflating: w2v_zh/word2vec_wiki_zh.model.bin.trainables.syn1neg.npy
#   inflating: w2v_zh/word2vec_wiki_zh.model.bin.wv.vectors.npy
# Archive:  model.zip
#    creating: model/
#    creating: model/CH_HLSQG_model/
#   inflating: model/CH_HLSQG_model/pytorch_model_2.bin
#   inflating: model/CH_HLSQG_model/pytorch_model_3.bin
#    creating: model/ENG_HLSQG_model/
#   inflating: model/ENG_HLSQG_model/pytorch_model_2.bin
#    creating: model/SQG_hl_id3_bert-base-chinese/
#   inflating: model/SQG_hl_id3_bert-base-chinese/bert_config.json
#   inflating: model/SQG_hl_id3_bert-base-chinese/pytorch_model.bin
#   inflating: model/SQG_hl_id3_bert-base-chinese/vocab.txt
#    creating: model/SQG_hl_id3_bert-base-uncased/
#   inflating: model/SQG_hl_id3_bert-base-uncased/bert_config.json
#   inflating: model/SQG_hl_id3_bert-base-uncased/pytorch_model.bin
# ...

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=17RNRQ5uhSiVCjn2OIpNGJ9LEQB30lN-D' -O tokenization.zip
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1MPl1vF5vpfKed2e7rjS2ndirkqZCVqQa' -O modeling.zip
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XuYWIToXeWSupPswXF3ZEmd2lohZ3Pg9' -O file_utils.zip
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1KIB7pm-WGI8L0Zr7anXE2Hcy6kwDy_X9' -O config.zip
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1y-LuLhX0hWjLNy1rEbjjOBHFNCoIKc5p' -O CH_HLSQG.zip
# Out:
# --2023-02-21 08:19:11--  https://docs.google.com/uc?export=download&id=17RNRQ5uhSiVCjn2OIpNGJ9LEQB30lN-D
# Resolving docs.google.com (docs.google.com)... 74.125.142.100, 74.125.142.138, 74.125.142.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kvllag52191g51o1gviehtuoqnh8glhk/1676967525000/02928050404646572593/*/17RNRQ5uhSiVCjn2OIpNGJ9LEQB30lN-D?e=download&uuid=b6d44305-fbcf-4366-ac43-514859142691 [following]
# ...
# --2023-02-21 08:19:11--  https://doc-0s-34-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kvllag52191g51o1gviehtuoqnh8glhk/1676967525000/02928050404646572593/*/17RNRQ5uhSiVCjn2OIpNGJ9LEQB30lN-D?e=download&uuid=b6d44305-fbcf-4366-ac43-514859142691
# ...

# %%
# !unzip tokenization.zip
# !unzip modeling.zip
# !unzip file_utils.zip
# !unzip config.zip
# !unzip CH_HLSQG.zip
# Out:
# Archive:  tokenization.zip
#   inflating: tokenization.py
# Archive:  modeling.zip
#   inflating: modeling.py
# Archive:  file_utils.zip
#   inflating: file_utils.py
# Archive:  config.zip
#   inflating: config.py
# Archive:  CH_HLSQG.zip
#   inflating: CH_HLSQG.py

# %% [markdown]
# ## Multiple Choices Question Generation

# %%
from pyserini.search.lucene import LuceneSearcher
from pyserini.index import IndexReader
from gensim import models
import re
import json
import random
import CH_HLSQG
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
# 載入 中文QGmodel、w2v model
ch_model = CH_HLSQG.BERT_HLSQG()
w2v_model = models.Word2Vec.load('/content/w2v_zh/word2vec_wiki_zh.model.bin')

# %% [markdown]
# ## 轉換為pysiniri指定的反向索引表，其中input和index分別為輸入和輸出的資料夾

# %%
# !python -m pyserini.index.lucene \
  --collection JsonCollection \
  --input /content/corpus \
  --language zh \
  --index Index/pttdataset \
  --generator DefaultLuceneDocumentGenerator \
  --threads 1 \
  --storePositions --storeDocvectors --storeRaw
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2023-02-21 08:19:50,674 INFO  [main] index.IndexCollection (IndexCollection.java:391) - Setting log level to INFO
# 2023-02-21 08:19:50,678 INFO  [main] index.IndexCollection (IndexCollection.java:394) - Starting indexer...
# 2023-02-21 08:19:50,681 INFO  [main] index.IndexCollection (IndexCollection.java:395) - ============ Loading Parameters ============
# 2023-02-21 08:19:50,682 INFO  [main] index.IndexCollection (IndexCollection.java:396) - DocumentCollection path: /content/corpus
# 2023-02-21 08:19:50,682 INFO  [main] index.IndexCollection (IndexCollection.java:397) - CollectionClass: JsonCollection
# 2023-02-21 08:19:50,683 INFO  [main] index.IndexCollection (IndexCollection.java:398) - Generator: DefaultLuceneDocumentGenerator
# 2023-02-21 08:19:50,683 INFO  [main] index.IndexCollection (IndexCollection.java:399) - Threads: 1
# ...

# %%
# 載入 Inverted Table
print('Loading Inverted Index for Ptt...')
searcher = LuceneSearcher('Index/pttdataset')
index_reader = IndexReader('/content/Index/pttdataset')
# Out:
# Loading Inverted Index for Ptt...

# %%
# 定義Retreiver 使用建好的Inverted_Index_Ptt_Chinese(Index/pttdataset)
def Retreiver(quesion):
  searcher.set_language('zh')
  hits = searcher.search(quesion, k=10)
  return hits

# 答案選項生成
def answerPosFinder(cxt, ans):
  start = cxt.find(ans)
  end = start+len(ans)
  ans_pos = [(m.start(), m.end()) for m in re.finditer(ans, cxt)]

  QGpairs=[]
  for i in ans_pos:
    pair = {"article":cxt,
            "answers":{
                "ans_detail":[
                  {
                      "tag":ans,
                      "start_at":i[0],
                      "end_at":i[1]
                  }            
                ]
            }
            }
    QGpairs.append(pair)
      
  return QGpairs

# 定義w2v
def word2vec_predict(w2v_model,predictWord,top_k=10,verbose=False):
  try:
    rt = []
    predict = w2v_model.wv.similar_by_word(predictWord, topn=top_k)
    for word in predict:
      rt.append(word[0])
    return rt
    
  except:
    print('字典裡沒這個word: {}!'.format(predictWord))
    return 'error'

def main():
    # 使用者輸入關鍵字詞。
    term_from_front_end_user = input("輸入關鍵字詞: ")
    topics = str(term_from_front_end_user)
    # 目前先用topic關鍵字的第一個詞來當答案。(下面是隨機選擇答案)
    QG_ans=topics.split()[0] 
    QG_ans=random.choice(topics.split())
    print(QG_ans)

    # 定義question set
    q_set=set()
    # 藉由topics(使用者的輸入)去找相關documents
    hits = Retreiver(topics)
    # 
    print("\n\n**********************")
    print("以下為與 "+QG_ans+" 有關的文章")
    print("**********************")
    for i in hits:
      # 拿取Retreiver回傳的document 裡的contents
      contents = json.loads(i.raw)["contents"]
      print(contents)
      # 從contents中找到答案(QG_ans)的位置並回傳qa(問題 答案位置)
      for qa in answerPosFinder(contents,QG_ans)[:5]:
        context = qa["article"]
        answer = qa["answers"]["ans_detail"][0]['tag']
        answer_start = qa["answers"]["ans_detail"][0]['start_at']
        # 找文章長度大於100的
        if len(context) >= 100:
          # 用context尋找問題 
          questions = ch_model.predict(context = context, answer = answer, answer_start = answer_start, BS = 1)
          for q in questions:
            # 判斷QG_ans是否在question裡面 找沒有的且長度大於12
            if not QG_ans in q:
              if len(q)>12:
                q_set.add(q)

    # 所有的question
    question_set = list(q_set)
    #處理[UNK]
    for index,q in enumerate(question_set):
      if "[UNK]" in q:
        question_set[index].replace("[UNK]","")

    question_set_len=len(question_set)
    choice_output = []
    # a_dict=[]
    # for i in question_set:
    #   a_dict.append(QG_ans)

    for k in range(question_set_len):
      top_k=5
      verbose=True
      # 相關選項list
      distrator = word2vec_predict(w2v_model,QG_ans,top_k,verbose)
      #print(distrator)
      if not distrator == 'error':
        for a in distrator:
          if QG_ans in a: 
            distrator.remove(a)
        # **CODE** 判斷distrator是否長度過短

        # 取前十個distrator來打亂隨機選擇
        distrator_10=distrator[:10]
        random.shuffle(distrator_10)
        ans = [QG_ans]
        ans.append(distrator_10[-3])
        ans.append(distrator_10[-2])
        ans.append(distrator_10[-1])
        random.shuffle(ans)
        # 例子 A:白血病 B:乳腺癌 C:腎病 D:前列腺癌
        choice_output.append(
              "A:" +ans[0]+"  "+
              "B:" +ans[1]+"  "+
              "C:" +ans[2]+"  "+
              "D:" +ans[3]+"  " 
        )
      else:
        return ["查不到這個詞彙，請重新搜尋 :「"+QG_ans+"」"]
    # 看選項有什麼
    for i in choice_output:
        print("選項:",i)

    # 最後要return的list 下面例子
    # Q1: 髓細胞會因為哪一種病變而發生異常的生長?
    # A:白血病 B:乳腺癌 C:腎病 D:前列腺癌
    question_set_ans=[]
    
    # 結合question_set choice_output
    for i, question in enumerate(question_set):
      question_set_ans.append("Q"+str(i+1)+": "+question)
      question_set_ans.append(choice_output[i])
    
    print("***********")
    print(question_set_ans[:12])
    print("***********")
    return question_set_ans[:12]

if __name__ == '__main__':
    main()
# Out:
# 輸入關鍵字詞: 民進黨
# 民進黨
#
#
# **********************
# 以下為與 民進黨 有關的文章
# **********************
#
# 前面居然有人跟我說「柯文哲是玄天上帝是綠共說的」
#
# 然後又看到很多人，沒跟上昨天八卦板的「直銷大會」
# 超級盛況，基於有參與到這整件盛事，就來做這個懶人包吧！
#
# ------------------------------------
# 柯文哲＝玄天上帝懶人包
# #直銷大會
# #宗教狂熱
#   ------------------------------------
# 事情起源：一篇違規的政問
# 2021年07月01日 20:55:19
# Wilsondenq發表一篇政問:「民進黨到底多怕柯文哲」
#
#
# 隨即遭到大量信徒回文激烈討論，內文自然都是捧柯捧上了天
#
# 頓時整個八卦板陷入一種狂熱，板主有整理如下：
#
#
# ●    1 ~33 7/01 Wilsondenq   □ [問卦] 民進黨到底多怕柯文哲？
#       2 + 4 7/01 xzcb2008     R: [問卦] 民進黨到底多怕柯文哲？
#       3 + 1 7/01 cigaretteass R: [問卦] 民進黨到底多怕柯文哲？
#       4 ~25 7/01 Leika        R: [問卦] 民進黨到底多怕柯文哲？
#       5   3 7/01 mix5172000   R: [問卦] 民進黨到底多怕柯文哲？
#       6   5 7/01 smallkaka    R: [問卦] 民進黨到底多怕柯文哲？
#       7   1 7/01 stratege     R: [問卦] 民進黨到底多怕柯文哲？
#       8 ~81 7/01 tigotigo     R: [問卦] 民進黨到底多怕柯文哲？
#       9 ~爆 7/01 kid725       R: [問卦] 民進黨到底多怕柯文哲？
#      10 +46 7/01 kiddingsa    R: [問卦] 民進黨到底多怕柯文哲？
#      11 ~15 7/01 sean3378     R: [問卦] 民進黨到底多怕柯文哲？
# ...
